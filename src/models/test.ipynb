# %%
import warnings
import pandas as pd
from unidecode import unidecode
import re
import json

# %%
df = pd.read_csv('/home/gian/Documents/real_state_price_calculator_pipeline/scraping.csv')

# %%
import json
import pandas as pd
from unidecode import unidecode

def create_amenities(df):
    warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

    tags_column = df['json'].apply(lambda x: json.loads(x)['Tags']).explode().dropna()
    modified_tags_column = tags_column.apply(lambda tag: 'has_' + re.sub(r'\s+', '_', unidecode(tag)))
    unique_columns = modified_tags_column.unique()

    amenities_df = pd.get_dummies(modified_tags_column).groupby(level=0).max()

    for column in unique_columns:
        if column not in amenities_df.columns:
            amenities_df[column] = 0
    
    return amenities_df

# %%
df_amenities = create_amenities(df)

# %%
df_amenities
# Out:
#        has_Academia  has_Aceita_animais  has_Acesso_para_deficientes  \
# 0             False                True                        False
# 3             False               False                        False
# 4             False               False                        False
# 6             False                True                        False
# 7             False               False                        False
# ...             ...                 ...                          ...
# 41922         False               False                        False
# 41923         False               False                        False
# 41924          True               False                        False
# 41925          True               False                        False
# 41926         False               False                        False
#
#        has_Ambientes_integrados  has_Andar_inteiro  has_Aquecimento  \
# 0                         False              False            False
# 3                         False              False            False
# 4                         False              False            False
# 6                         False              False            False
# 7                         False              False            False
# ...                         ...                ...              ...
# 41922                     False              False            False
# 41923                     False              False            False
# 41924                     False              False            False
# 41925                     False              False            False
# 41926                     False              False            False
#
#        has_Ar-condicionado  has_Area_de_lazer  has_Area_de_servico  \
# 0                    False              False                False
# 3                     True              False                False
# 4                     True              False                False
# 6                     True              False                False
# 7                     True              False                False
# ...                    ...                ...                  ...
# 41922                 True              False                False
# 41923                 True              False                False
# 41924                 True              False                False
# 41925                 True              False                False
# 41926                False              False                False
#
#        has_Arenoso  ...  has_Ventilacao_natural  has_Vestiario  \
# 0            False  ...                   False          False
# 3            False  ...                   False          False
# 4            False  ...                   False          False
# 6            False  ...                   False          False
# 7            False  ...                   False          False
# ...            ...  ...                     ...            ...
# 41922        False  ...                   False          False
# 41923        False  ...                   False          False
# 41924        False  ...                   False          False
# 41925        False  ...                   False          False
# 41926        False  ...                   False          False
#
#        has_Vestiario_para_diaristas  has_Vigia  has_Vista_exterior  \
# 0                             False      False               False
# 3                             False      False               False
# 4                             False      False               False
# 6                             False      False               False
# 7                             False      False               False
# ...                             ...        ...                 ...
# 41922                         False      False               False
# 41923                         False      False               False
# 41924                         False      False               False
# 41925                         False      False               False
# 41926                         False      False               False
#
#        has_Vista_panoramica  has_Vista_para_a_montanha  has_Vista_para_lago  \
# 0                     False                      False                False
# 3                     False                      False                False
# 4                     False                      False                False
# 6                     False                      False                False
# 7                     False                      False                False
# ...                     ...                        ...                  ...
# 41922                 False                      False                False
# 41923                 False                      False                False
# 41924                 False                      False                False
# 41925                 False                      False                False
# 41926                 False                      False                False
#
#        has_Vista_para_o_mar  has_Zelador
# 0                     False        False
# 3                     False        False
# 4                     False        False
# 6                     False        False
# 7                     False        False
# ...                     ...          ...
# 41922                 False        False
# 41923                 False        False
# 41924                 False        False
# 41925                 False        False
# 41926                 False        False
#
# [24470 rows x 179 columns]

# %%
df_amenities.isnull().sum()
# Out:
# has_Academia                   0
# has_Aceita_animais             0
# has_Acesso_para_deficientes    0
# has_Ambientes_integrados       0
# has_Andar_inteiro              0
#                               ..
# has_Vista_panoramica           0
# has_Vista_para_a_montanha      0
# has_Vista_para_lago            0
# has_Vista_para_o_mar           0
# has_Zelador                    0
# Length: 179, dtype: int64
